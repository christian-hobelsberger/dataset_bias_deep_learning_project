# %%
from PIL import Image
import glob
import requests


import os

# %%
# function for downloading images from the labelme website
def download_images(url, folder, index_count, image_label_long_string):

    # Fetch HTML content of the page
    response = requests.get(url)
    html_content = response.text

    # Use while loop to find all ."jpg" hyperlink things in the HTML text thing
    index = 0
    while True:
        index = html_content.find('.jpg', index)
        
        # The indices are only -1 if no instance of the substring was found (i.e. end of file)
        if index == -1:
            break
            
        # Find the start of the image title
        start_index = html_content.rfind('"', 0, index)
        if start_index == -1:
            break
            
        # Find the end of image title
        end_index = html_content.find('"', index)
        if end_index == -1:
            break
        

        # Get full image url
        image_url = url + html_content[start_index + 1:end_index]
        
        filename = os.path.join(folder, os.path.basename(image_url))
        
        # get image name:
        img_name = html_content[start_index + 1:end_index]
        
        # extra identifier to solve problems with overlapping names
        img_identifier = str(index_count) + str(index_count) + str(index_count) + ".jpg"
        filename = filename.replace(".jpg", img_identifier)
        
        if filename in image_label_long_string:
            # Download image
            image_retrieval = requests.get(image_url)
            if image_retrieval.status_code == 200:      # this is a quick safeguard to guarantee that the retrieval was succesfull
                # Save the image to folder
                with open(filename, 'wb') as file:
                    file.write(image_retrieval.content)
                
        # Update index so that the next jpg can be found
        index = end_index + 1

# %%
# function for generating the list of folder urls from the labelme website
def find_folders(do_annotations_bool):
    if do_annotations_bool:
        url = "http://labelme.csail.mit.edu/Annotations/"
    else:
        url = "http://labelme.csail.mit.edu/Images/"
  
    request = requests.get(url)
    html_content = request.text
    
    folder_list = []

    start_index = 0

    while start_index != -1:
        
        # all folder hyperlinks start with the alt=... substring, and end at double quotes.
        start_index = html_content.find('alt="[DIR]"></td><td><a href="', start_index) + 30
        stop_index = html_content.find('"', start_index)

        # quit in case no additional folder was found
        if start_index == 29 or stop_index == -1: 
            break
            
        folder_url = url + html_content[start_index:stop_index]

        folder_list.append(folder_url)
        start_index = stop_index + 1

    return(folder_list)

# %%
# function for getting the associated image labels from the labelme website
def obtain_labels_labelMe(folder_url, index_count):

    LabelMe_labels = []
   
    request = requests.get(folder_url)
    html_folder_content = request.text
    html_length = len(html_folder_content)

    index = 0

    # while loop to find the xml files in the current folder
    while True:
        index = html_folder_content.find('.xml', index)

        # break out of while loop if all xmls have been found
        if index == -1:
            break
        # Find the start of the URL
        begin_index = html_folder_content.rfind('"', 0, index)

        if begin_index == -1:
            break
        # Find the end of the URL
        end_index = html_folder_content.find('"', index)

        if end_index == -1:
            break

        # obtain xml name
        xml_name = html_folder_content[begin_index:end_index]

        xml_url = folder_url + html_folder_content[begin_index + 1:end_index]


        start_index = 0


        request = requests.get(xml_url)
        html_content = request.text

        
        
        label_begin_start_index = html_content.find('<filename>', start_index) + 10
        label_end_stop_index = html_content.find('</filename>', start_index)

        label_begin_start_index_pt2 = html_content.find('<folder>', start_index) + 8
        label_end_stop_index_pt2 = html_content.find('</folder>', start_index)

        # initialize the label with the name of the .jpg image (which is used for sorting purposes later)
        label_pt1 = html_content[label_begin_start_index:label_end_stop_index]
        label_pt2 = html_content[label_begin_start_index_pt2:label_end_stop_index_pt2]
        
        label = label_pt1 + "><" + label_pt2 + ">>"
        
        label_identifier = str(index_count) + str(index_count) + str(index_count) + ".jpg"
        
        label = label.replace(".jpg", label_identifier)



        # Now store all the labels that exist in the annotation part of the jpg
        while start_index != -1:
            start_index = html_content.find('<name>', start_index) + 6
            stop_index = html_content.find('</name>', start_index)

            # break out if no more labels are present in the annotation
            if start_index == 5 or stop_index == -1:
                break

            # some annotations were added after publication of the unbiasedness paper, 
            # and they also have a tendency to be wrong, so these labels are not added
            forbidden_years = ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024"]

            if not any(sub_string in html_content[stop_index:min([stop_index+250, html_length])] for sub_string in forbidden_years):
                label = label + " " + html_content[start_index:stop_index]

            start_index = stop_index+1

        # Add all labels to corresponding annotation
        LabelMe_labels.append(label)

        # go to the next xml in the folder
        index = end_index + 50
        
    return(LabelMe_labels)

# %%
# downloading labelme annotations and storing them in a .txt file:

# retrieve all folder urls which have the images
url_folders = find_folders(True)

# uncomment next line for testing (here only images in the first 3 folders are downloaded)
# url_folders = url_folders[0:3]   



labelMe_label_list = []
count = 0

# count = X
# url_folders = url_folders[count:len(url_folders)]

for folder_url in url_folders:
    print(folder_url)
    new_labels = obtain_labels_labelMe(folder_url, count)
    
    for labels in new_labels:
        labelMe_label_list.append(labels)
    
    print("Just finished count:", count, ". Percentage done:", 100*(count+1)/296)
    count += 1
# Out:
# http://labelme.csail.mit.edu/Annotations/05june05_static_indoor/
# Just finished count: 0 . Percentage done: 0.33783783783783783
# http://labelme.csail.mit.edu/Annotations/05june05_static_street_boston/
# Just finished count: 1 . Percentage done: 0.6756756756756757
# http://labelme.csail.mit.edu/Annotations/05june05_static_street_porter/
# Just finished count: 2 . Percentage done: 1.0135135135135136
# http://labelme.csail.mit.edu/Annotations/10feb04_static_cars_highland/
# Just finished count: 3 . Percentage done: 1.3513513513513513
# http://labelme.csail.mit.edu/Annotations/10feb04_static_cars_techsquare_lot/
# Just finished count: 4 . Percentage done: 1.6891891891891893
# http://labelme.csail.mit.edu/Annotations/10feb04_static_cars_underground/
# Just finished count: 5 . Percentage done: 2.027027027027027
# http://labelme.csail.mit.edu/Annotations/10feb04_static_techsquare/
# Just finished count: 6 . Percentage done: 2.364864864864865
# http://labelme.csail.mit.edu/Annotations/30may05_static_street_cambridge/
# Just finished count: 7 . Percentage done: 2.7027027027027026
# http://labelme.csail.mit.edu/Annotations/april21_static_outdoor_davis/
# Just finished count: 8 . Percentage done: 3.0405405405405403
# http://labelme.csail.mit.edu/Annotations/april21_static_outdoor_kendall/
# Just finished count: 9 . Percentage done: 3.3783783783783785
# http://labelme.csail.mit.edu/Annotations/aug1_static_atb_office_bldg400/
# Just finished count: 10 . Percentage done: 3.7162162162162162
# http://labelme.csail.mit.edu/Annotations/aug1_static_kpm_kitchen/
# Just finished count: 11 . Percentage done: 4.054054054054054
# http://labelme.csail.mit.edu/Annotations/aug1_static_kpm_office_bldg200/
# Just finished count: 12 . Percentage done: 4.391891891891892
# http://labelme.csail.mit.edu/Annotations/aug21_seq1_bldg400/
# Just finished count: 13 . Percentage done: 4.72972972972973
# http://labelme.csail.mit.edu/Annotations/aug21_seq2_bldg400/
# Just finished count: 14 . Percentage done: 5.0675675675675675
# http://labelme.csail.mit.edu/Annotations/aug21_seq3_bldg400/
# Just finished count: 15 . Percentage done: 5.405405405405405
# http://labelme.csail.mit.edu/Annotations/aug21_seq4_bldg400/
# Just finished count: 16 . Percentage done: 5.743243243243243
# http://labelme.csail.mit.edu/Annotations/aug21_seq5_bldg400/
# Just finished count: 17 . Percentage done: 6.081081081081081
# http://labelme.csail.mit.edu/Annotations/barcelona_static_street/
# Just finished count: 18 . Percentage done: 6.418918918918919
# http://labelme.csail.mit.edu/Annotations/bathroom_indoor_256x256_static/
# Just finished count: 19 . Percentage done: 6.756756756756757
# http://labelme.csail.mit.edu/Annotations/bedroom_indoor_256x256_static/
# Just finished count: 20 . Percentage done: 7.094594594594595
# http://labelme.csail.mit.edu/Annotations/boston_static_indoor/
# Just finished count: 21 . Percentage done: 7.4324324324324325
# http://labelme.csail.mit.edu/Annotations/boston_static_march/
# Just finished count: 22 . Percentage done: 7.77027027027027
# http://labelme.csail.mit.edu/Annotations/boston_static_street/
# Just finished count: 23 . Percentage done: 8.108108108108109
# http://labelme.csail.mit.edu/Annotations/conference_indoor_set2_web_static/
# Just finished count: 24 . Percentage done: 8.445945945945946
# http://labelme.csail.mit.edu/Annotations/corridor_indoor_set2_256x256_static/
# Just finished count: 25 . Percentage done: 8.783783783783784
# http://labelme.csail.mit.edu/Annotations/country_static_90rocks/
# Just finished count: 26 . Percentage done: 9.121621621621621
# http://labelme.csail.mit.edu/Annotations/country_static_132pumpkins/
# Just finished count: 27 . Percentage done: 9.45945945945946
# http://labelme.csail.mit.edu/Annotations/crystals_crystallization_processes/
# Just finished count: 28 . Percentage done: 9.797297297297296
# http://labelme.csail.mit.edu/Annotations/database_static_street/
# Just finished count: 29 . Percentage done: 10.135135135135135
# http://labelme.csail.mit.edu/Annotations/dec_static_office/
# Just finished count: 30 . Percentage done: 10.472972972972974
# http://labelme.csail.mit.edu/Annotations/dec_static_street/
# Just finished count: 31 . Percentage done: 10.81081081081081
# http://labelme.csail.mit.edu/Annotations/feb24_bldg200_fl7_a/
# Just finished count: 32 . Percentage done: 11.14864864864865
# http://labelme.csail.mit.edu/Annotations/feb24_bldg200_fl9_d/
# Just finished count: 33 . Percentage done: 11.486486486486486
# http://labelme.csail.mit.edu/Annotations/fink_static_indoor_officepanorama_small/
# Just finished count: 34 . Percentage done: 11.824324324324325
# http://labelme.csail.mit.edu/Annotations/indoor_static_20apples/
# Just finished count: 35 . Percentage done: 12.162162162162161
# http://labelme.csail.mit.edu/Annotations/indoor_static_20oranges/
# Just finished count: 36 . Percentage done: 12.5
# http://labelme.csail.mit.edu/Annotations/invalid../
# Just finished count: 37 . Percentage done: 12.837837837837839
# http://labelme.csail.mit.edu/Annotations/labelme2/
# Just finished count: 38 . Percentage done: 13.175675675675675
# http://labelme.csail.mit.edu/Annotations/livingroom_indoor_256x256_static/
# Just finished count: 39 . Percentage done: 13.513513513513514
# http://labelme.csail.mit.edu/Annotations/lobby_indoor_256x256_static/
# Just finished count: 40 . Percentage done: 13.85135135135135
# http://labelme.csail.mit.edu/Annotations/madrid_static_street/
# Just finished count: 41 . Percentage done: 14.18918918918919
# http://labelme.csail.mit.edu/Annotations/movie/
# Just finished count: 42 . Percentage done: 14.527027027027026
# http://labelme.csail.mit.edu/Annotations/nov6_static_outdoor/
# Just finished count: 43 . Percentage done: 14.864864864864865
# http://labelme.csail.mit.edu/Annotations/nov7_static_outdoor/
# Just finished count: 44 . Percentage done: 15.202702702702704
# http://labelme.csail.mit.edu/Annotations/nov25_static_corridor/
# Just finished count: 45 . Percentage done: 15.54054054054054
# http://labelme.csail.mit.edu/Annotations/nov25_static_office/
# Just finished count: 46 . Percentage done: 15.878378378378379
# http://labelme.csail.mit.edu/Annotations/nov25_static_street/
# Just finished count: 47 . Percentage done: 16.216216216216218
# http://labelme.csail.mit.edu/Annotations/oct6_static_atb_office_bldg400/
# Just finished count: 48 . Percentage done: 16.554054054054053
# http://labelme.csail.mit.edu/Annotations/oct6_static_office_bldg200/
# Just finished count: 49 . Percentage done: 16.89189189189189
# http://labelme.csail.mit.edu/Annotations/oct6_static_outdoor/
# Just finished count: 50 . Percentage done: 17.22972972972973
# http://labelme.csail.mit.edu/Annotations/oct7_seq1_bldg400_fl6/
# Just finished count: 51 . Percentage done: 17.56756756756757
# http://labelme.csail.mit.edu/Annotations/oct7_seq2_bldg400_fl6/
# Just finished count: 52 . Percentage done: 17.905405405405407
# http://labelme.csail.mit.edu/Annotations/oct28_static_msu/
# Just finished count: 53 . Percentage done: 18.243243243243242
# http://labelme.csail.mit.edu/Annotations/oct_static_bldg200_corridor/
# Just finished count: 54 . Percentage done: 18.58108108108108
# http://labelme.csail.mit.edu/Annotations/oct_static_bldg400_corridor/
# Just finished count: 55 . Percentage done: 18.91891891891892
# http://labelme.csail.mit.edu/Annotations/office_indoor_256x256_static/
# Just finished count: 56 . Percentage done: 19.256756756756758
# http://labelme.csail.mit.edu/Annotations/office_indoor_set2_web_static/
# Just finished count: 57 . Percentage done: 19.594594594594593
# http://labelme.csail.mit.edu/Annotations/paris_static_street/
# Just finished count: 58 . Percentage done: 19.93243243243243
# http://labelme.csail.mit.edu/Annotations/q8LwLte1'%20OR%20822=(SELECT%20822%20FROM%20PG_SLEEP(15))--/
# Just finished count: 59 . Percentage done: 20.27027027027027
# http://labelme.csail.mit.edu/Annotations/rXYdQYFy'))%20OR%2089=(SELECT%2089%20FROM%20PG_SLEEP(15))--/
# Just finished count: 60 . Percentage done: 20.60810810810811
# http://labelme.csail.mit.edu/Annotations/response.write(9298394*9351691)/
# Just finished count: 61 . Percentage done: 20.945945945945947
# http://labelme.csail.mit.edu/Annotations/response.write(9906953*9749552)/
# Just finished count: 62 . Percentage done: 21.283783783783782
# http://labelme.csail.mit.edu/Annotations/sandbox/
# Just finished count: 63 . Percentage done: 21.62162162162162
# http://labelme.csail.mit.edu/Annotations/sep1_seq1_bldg400_outdoor/
# Just finished count: 64 . Percentage done: 21.95945945945946
# http://labelme.csail.mit.edu/Annotations/sep1_seq2_bldg400_outdoor/
# Just finished count: 65 . Percentage done: 22.2972972972973
# http://labelme.csail.mit.edu/Annotations/sep1_seq3_bldg400_outdoor/
# Just finished count: 66 . Percentage done: 22.635135135135137
# http://labelme.csail.mit.edu/Annotations/sep1_seq4_bldg400_outdoor/
# Just finished count: 67 . Percentage done: 22.972972972972972
# http://labelme.csail.mit.edu/Annotations/seq_april29_04_stata_fl4_drayfoos_atb_a/
# Just finished count: 68 . Percentage done: 23.31081081081081
# http://labelme.csail.mit.edu/Annotations/seq_april29_04_stata_fl4_drayfoos_atb_b/
# Just finished count: 69 . Percentage done: 23.64864864864865
# http://labelme.csail.mit.edu/Annotations/seq_feb19_bldg400_fl6_a/
# Just finished count: 70 . Percentage done: 23.986486486486488
# http://labelme.csail.mit.edu/Annotations/seq_feb21_bldg400_fl6_b/
# Just finished count: 71 . Percentage done: 24.324324324324323
# http://labelme.csail.mit.edu/Annotations/seq_feb21_bldg400_fl6_c/
# Just finished count: 72 . Percentage done: 24.66216216216216
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl7_b/
# Just finished count: 73 . Percentage done: 25.0
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl7_c/
# Just finished count: 74 . Percentage done: 25.33783783783784
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl7_d/
# Just finished count: 75 . Percentage done: 25.675675675675677
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl7_e/
# Just finished count: 76 . Percentage done: 26.013513513513512
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl9_a/
# Just finished count: 77 . Percentage done: 26.35135135135135
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl9_b/
# Just finished count: 78 . Percentage done: 26.68918918918919
# http://labelme.csail.mit.edu/Annotations/seq_feb24_bldg200_fl9_c/
# Just finished count: 79 . Percentage done: 27.027027027027028
# http://labelme.csail.mit.edu/Annotations/seq_feb24_outdoors1/
# Just finished count: 80 . Percentage done: 27.364864864864863
# http://labelme.csail.mit.edu/Annotations/seq_feb24_outdoors2/
# Just finished count: 81 . Percentage done: 27.7027027027027
# http://labelme.csail.mit.edu/Annotations/seq_feb24_outdoors3/
# Just finished count: 82 . Percentage done: 28.04054054054054
# http://labelme.csail.mit.edu/Annotations/seq_feb24_outdoors4/
# Just finished count: 83 . Percentage done: 28.37837837837838
# http://labelme.csail.mit.edu/Annotations/seq_feb24_outdoors5/
# Just finished count: 84 . Percentage done: 28.716216216216218
# http://labelme.csail.mit.edu/Annotations/seq_indoor_lobby10_mit_cap11/
# Just finished count: 85 . Percentage done: 29.054054054054053
# http://labelme.csail.mit.edu/Annotations/seq_indoor_lobby10_mit_cap12/
# Just finished count: 86 . Percentage done: 29.39189189189189
# http://labelme.csail.mit.edu/Annotations/seq_indoor_lobby10_mit_cap13/
# Just finished count: 87 . Percentage done: 29.72972972972973
# http://labelme.csail.mit.edu/Annotations/seq_indoor_statacenter_mit_cap5/
# Just finished count: 88 . Percentage done: 30.06756756756757
# http://labelme.csail.mit.edu/Annotations/seq_indoor_statacenter_mit_cap6/
# Just finished count: 89 . Percentage done: 30.405405405405407
# http://labelme.csail.mit.edu/Annotations/seq_indoor_statacenter_mit_cap7/
# Just finished count: 90 . Percentage done: 30.743243243243242
# http://labelme.csail.mit.edu/Annotations/seq_outdoor_statacenter_mit_clip1/
# Just finished count: 91 . Percentage done: 31.08108108108108
# http://labelme.csail.mit.edu/Annotations/seq_outdoor_statacenter_mit_clip2/
# Just finished count: 92 . Percentage done: 31.41891891891892
# http://labelme.csail.mit.edu/Annotations/seq_robotics_csie_ntu_driving_road_highway_apr_2006/
# Just finished count: 93 . Percentage done: 31.756756756756758
# http://labelme.csail.mit.edu/Annotations/seq_robotics_csie_ntu_driving_road_urban_apr_2006/
# Just finished count: 94 . Percentage done: 32.0945945945946
# http://labelme.csail.mit.edu/Annotations/seq_sam_davies_webcam_street_outdoor/
# Just finished count: 95 . Percentage done: 32.432432432432435
# http://labelme.csail.mit.edu/Annotations/seq_stereo_office_stata_oct24/
# Just finished count: 96 . Percentage done: 32.770270270270274
# http://labelme.csail.mit.edu/Annotations/seq_submitted_Zoran_Zivkovic_indoor_Home1/
# Just finished count: 97 . Percentage done: 33.108108108108105
# http://labelme.csail.mit.edu/Annotations/seq_submitted_Zoran_Zivkovic_indoor_Home2/
# Just finished count: 98 . Percentage done: 33.445945945945944
# http://labelme.csail.mit.edu/Annotations/seq_submitted_alessandro_perina_sense_cam_aug_2011/
# Just finished count: 99 . Percentage done: 33.78378378378378
# http://labelme.csail.mit.edu/Annotations/seq_submitted_dash_denver_kitchen/
# Just finished count: 100 . Percentage done: 34.12162162162162
# http://labelme.csail.mit.edu/Annotations/spatial_envelope_256x256_static_8outdoorcategories/
# Just finished count: 101 . Percentage done: 34.45945945945946
# http://labelme.csail.mit.edu/Annotations/stata_april_static_office/
# Just finished count: 102 . Percentage done: 34.7972972972973
# http://labelme.csail.mit.edu/Annotations/static_256x256_web_globalandscape/
# Just finished count: 103 . Percentage done: 35.13513513513514
# http://labelme.csail.mit.edu/Annotations/static_256x256_web_tv_database/
# Just finished count: 104 . Percentage done: 35.472972972972975
# http://labelme.csail.mit.edu/Annotations/static_amphitheater_indoor_web/
# Just finished count: 105 . Percentage done: 35.810810810810814
# http://labelme.csail.mit.edu/Annotations/static_animal1200_256x256/
# Just finished count: 106 . Percentage done: 36.148648648648646
# http://labelme.csail.mit.edu/Annotations/static_barcelona_street_city_outdoor_2_2005/
# Just finished count: 107 . Percentage done: 36.486486486486484
# http://labelme.csail.mit.edu/Annotations/static_barcelona_street_city_outdoor_2005/
# Just finished count: 108 . Percentage done: 36.82432432432432
# http://labelme.csail.mit.edu/Annotations/static_bolivia_outdoor_city/
# Just finished count: 109 . Percentage done: 37.16216216216216
# http://labelme.csail.mit.edu/Annotations/static_boston_city_street_outdoor_crowd/
# Just finished count: 110 . Percentage done: 37.5
# http://labelme.csail.mit.edu/Annotations/static_boston_street/
# Just finished count: 111 . Percentage done: 37.83783783783784
# http://labelme.csail.mit.edu/Annotations/static_boston_street_april/
# Just finished count: 112 . Percentage done: 38.17567567567568
# http://labelme.csail.mit.edu/Annotations/static_cambridge_street_outdoor_2006/
# Just finished count: 113 . Percentage done: 38.513513513513516
# http://labelme.csail.mit.edu/Annotations/static_city_wuhan_china/
# Just finished count: 114 . Percentage done: 38.851351351351354
# http://labelme.csail.mit.edu/Annotations/static_coast_landscape_outdoor/
# Just finished count: 115 . Percentage done: 39.189189189189186
# http://labelme.csail.mit.edu/Annotations/static_coast_palafrugel_outdoor_spain/
# Just finished count: 116 . Percentage done: 39.527027027027025
# http://labelme.csail.mit.edu/Annotations/static_crops_16classes_iccv2005/
# Just finished count: 117 . Percentage done: 39.86486486486486
# http://labelme.csail.mit.edu/Annotations/static_dartmouth_hanover_june_2006/
# Just finished count: 118 . Percentage done: 40.2027027027027
# http://labelme.csail.mit.edu/Annotations/static_embarrassing_iccv05_moments/
# Just finished count: 119 . Percentage done: 40.54054054054054
# http://labelme.csail.mit.edu/Annotations/static_emptyroom_indoor/
# Just finished count: 120 . Percentage done: 40.87837837837838
# http://labelme.csail.mit.edu/Annotations/static_eyemovements_2005/
# Just finished count: 121 . Percentage done: 41.21621621621622
# http://labelme.csail.mit.edu/Annotations/static_eyemovurban_audeoliva/
# Just finished count: 122 . Percentage done: 41.554054054054056
# http://labelme.csail.mit.edu/Annotations/static_formentera_outdoor_landscape_coast/
# Just finished count: 123 . Percentage done: 41.891891891891895
# http://labelme.csail.mit.edu/Annotations/static_harvard_outdoor_street/
# Just finished count: 124 . Percentage done: 42.229729729729726
# http://labelme.csail.mit.edu/Annotations/static_hotel_room_indoor/
# Just finished count: 125 . Percentage done: 42.567567567567565
# http://labelme.csail.mit.edu/Annotations/static_houses_boston_2005/
# Just finished count: 126 . Percentage done: 42.9054054054054
# http://labelme.csail.mit.edu/Annotations/static_indoor_2005_china/
# Just finished count: 127 . Percentage done: 43.24324324324324
# http://labelme.csail.mit.edu/Annotations/static_indoor_bathroom/
# Just finished count: 128 . Percentage done: 43.58108108108108
# http://labelme.csail.mit.edu/Annotations/static_indoor_bedroom_web/
# Just finished count: 129 . Percentage done: 43.91891891891892
# http://labelme.csail.mit.edu/Annotations/static_indoor_comerce/
# Just finished count: 130 . Percentage done: 44.25675675675676
# http://labelme.csail.mit.edu/Annotations/static_indoor_corridor/
# Just finished count: 131 . Percentage done: 44.5945945945946
# http://labelme.csail.mit.edu/Annotations/static_indoor_database_by_aude_oliva/
# Just finished count: 132 . Percentage done: 44.932432432432435
# http://labelme.csail.mit.edu/Annotations/static_indoor_dining/
# Just finished count: 133 . Percentage done: 45.270270270270274
# http://labelme.csail.mit.edu/Annotations/static_indoor_home_set1/
# Just finished count: 134 . Percentage done: 45.608108108108105
# http://labelme.csail.mit.edu/Annotations/static_indoor_kitchen/
# Just finished count: 135 . Percentage done: 45.945945945945944
# http://labelme.csail.mit.edu/Annotations/static_indoor_mixed/
# Just finished count: 136 . Percentage done: 46.28378378378378
# http://labelme.csail.mit.edu/Annotations/static_indoor_mixed2/
# Just finished count: 137 . Percentage done: 46.62162162162162
# http://labelme.csail.mit.edu/Annotations/static_indoor_office/
# Just finished count: 138 . Percentage done: 46.95945945945946
# http://labelme.csail.mit.edu/Annotations/static_industrial/
# Just finished count: 139 . Percentage done: 47.2972972972973
# http://labelme.csail.mit.edu/Annotations/static_italy_city_outdoor/
# Just finished count: 140 . Percentage done: 47.63513513513514
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_bird_web_database_egret/
# Just finished count: 141 . Percentage done: 47.972972972972975
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_bird_web_database_mandarin/
# Just finished count: 142 . Percentage done: 48.310810810810814
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_bird_web_database_owl/
# Just finished count: 143 . Percentage done: 48.648648648648646
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_bird_web_database_puffin/
# Just finished count: 144 . Percentage done: 48.986486486486484
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_bird_web_database_toucan/
# Just finished count: 145 . Percentage done: 49.32432432432432
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_bird_web_database_wood_duck/
# Just finished count: 146 . Percentage done: 49.66216216216216
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_admiral/
# Just finished count: 147 . Percentage done: 50.0
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_black_swallowtail/
# Just finished count: 148 . Percentage done: 50.33783783783784
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_machaon/
# Just finished count: 149 . Percentage done: 50.67567567567568
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_monarch_closed/
# Just finished count: 150 . Percentage done: 51.013513513513516
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_monarch_open/
# Just finished count: 151 . Percentage done: 51.351351351351354
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_peacock/
# Just finished count: 152 . Percentage done: 51.689189189189186
# http://labelme.csail.mit.edu/Annotations/static_lana_lazebnik_butterflies_web_database_zebra/
# Just finished count: 153 . Percentage done: 52.027027027027025
# http://labelme.csail.mit.edu/Annotations/static_lu_wei_feb_2006/
# Just finished count: 154 . Percentage done: 52.36486486486486
# http://labelme.csail.mit.edu/Annotations/static_madrid_outdoor_august_2005/
# Just finished count: 155 . Percentage done: 52.7027027027027
# http://labelme.csail.mit.edu/Annotations/static_mexico/
# Just finished count: 156 . Percentage done: 53.04054054054054
# http://labelme.csail.mit.edu/Annotations/static_nature_web_outdoor_animal/
# Just finished count: 157 . Percentage done: 53.37837837837838
# http://labelme.csail.mit.edu/Annotations/static_newyork_city_urban/
# Just finished count: 158 . Percentage done: 53.71621621621622
# http://labelme.csail.mit.edu/Annotations/static_newyork_cvpr_brussell_june_2006/
# Just finished count: 159 . Percentage done: 54.054054054054056
# http://labelme.csail.mit.edu/Annotations/static_newyork_cvpr_celiu_june_2006/
# Just finished count: 160 . Percentage done: 54.391891891891895
# http://labelme.csail.mit.edu/Annotations/static_newyork_cvpr_embarrassing_june_2006/
# Just finished count: 161 . Percentage done: 54.729729729729726
# http://labelme.csail.mit.edu/Annotations/static_office_bldg400/
# Just finished count: 162 . Percentage done: 55.067567567567565
# http://labelme.csail.mit.edu/Annotations/static_outdoor_aerial/
# Just finished count: 163 . Percentage done: 55.4054054054054
# http://labelme.csail.mit.edu/Annotations/static_outdoor_airport/
# Just finished count: 164 . Percentage done: 55.74324324324324
# http://labelme.csail.mit.edu/Annotations/static_outdoor_anchorage_alaska_usa/
# Just finished count: 165 . Percentage done: 56.08108108108108
# http://labelme.csail.mit.edu/Annotations/static_outdoor_banff_calgary_canada/
# Just finished count: 166 . Percentage done: 56.41891891891892
# http://labelme.csail.mit.edu/Annotations/static_outdoor_bay_area_submitted_alyosha_efros/
# Just finished count: 167 . Percentage done: 56.75675675675676
# http://labelme.csail.mit.edu/Annotations/./static_outdoor_bozeman_montana_usa%250abcc:009247.27339-30451.27339.13dfd.19552.2@bxss.me/
# Just finished count: 168 . Percentage done: 57.0945945945946
# http://labelme.csail.mit.edu/Annotations/static_outdoor_bozeman_montana_usa&amp;amp;n923077=v947759/
# Just finished count: 169 . Percentage done: 57.432432432432435
# http://labelme.csail.mit.edu/Annotations/./static_outdoor_bozeman_montana_usa&amp;lt;esi:include%20src=&amp;quot;http:/
# Just finished count: 170 . Percentage done: 57.770270270270274
# http://labelme.csail.mit.edu/Annotations/static_outdoor_bozeman_montana_usa'&amp;quot;()&amp;amp;%25&amp;lt;zzz&amp;gt;&amp;lt;ScRiPt%20&amp;gt;mC94(9170)&amp;lt;/
# Just finished count: 171 . Percentage done: 58.108108108108105
# http://labelme.csail.mit.edu/Annotations/static_outdoor_bozeman_montana_usa'%7c%7cDBMS_PIPE.RECEIVE_MESSAGE(CHR(98)%7c%7cCHR(98)%7c%7cCHR(98),15)%7c%7c'/
# Just finished count: 172 . Percentage done: 58.445945945945944
# http://labelme.csail.mit.edu/Annotations/static_outdoor_bozeman_montana_usa/
# Just finished count: 173 . Percentage done: 58.78378378378378
# http://labelme.csail.mit.edu/Annotations/static_outdoor_bozeman_montana_usa9882611/
# Just finished count: 174 . Percentage done: 59.12162162162162
# http://labelme.csail.mit.edu/Annotations/static_outdoor_budapest_submitted_alyosha_efros/
# Just finished count: 175 . Percentage done: 59.45945945945946
# http://labelme.csail.mit.edu/Annotations/static_outdoor_china_beijing_iccv05/
# Just finished count: 176 . Percentage done: 59.7972972972973
# http://labelme.csail.mit.edu/Annotations/static_outdoor_city_laredo_spain/
# Just finished count: 177 . Percentage done: 60.13513513513514
# http://labelme.csail.mit.edu/Annotations/static_outdoor_il_giocco_lucca_italy/
# Just finished count: 178 . Percentage done: 60.472972972972975
# http://labelme.csail.mit.edu/Annotations/static_outdoor_italy_submitted_alyosha_efros/
# Just finished count: 179 . Percentage done: 60.810810810810814
# http://labelme.csail.mit.edu/Annotations/static_outdoor_mallorca_spain/
# Just finished count: 180 . Percentage done: 61.148648648648646
# http://labelme.csail.mit.edu/Annotations/static_outdoor_montana_usa/
# Just finished count: 181 . Percentage done: 61.486486486486484
# http://labelme.csail.mit.edu/Annotations/static_outdoor_nature_florida_photos_by_fredo_durand/
# Just finished count: 182 . Percentage done: 61.82432432432432
# http://labelme.csail.mit.edu/Annotations/static_outdoor_nature_galapagos_photos_by_fredo_durand/
# Just finished count: 183 . Percentage done: 62.16216216216216
# http://labelme.csail.mit.edu/Annotations/static_outdoor_nature_park_forest_san_jose_california/
# Just finished count: 184 . Percentage done: 62.5
# http://labelme.csail.mit.edu/Annotations/static_outdoor_nature_squirrel_photos_by_fredo_durand/
# Just finished count: 185 . Percentage done: 62.83783783783784
# http://labelme.csail.mit.edu/Annotations/static_outdoor_nature_tanzania_photos_by_fredo_durand/
# Just finished count: 186 . Percentage done: 63.17567567567568
# http://labelme.csail.mit.edu/Annotations/static_outdoor_oxford_submitted_alyosha_efros/
# Just finished count: 187 . Percentage done: 63.513513513513516
# http://labelme.csail.mit.edu/Annotations/static_outdoor_prague_submitted_alyosha_efros/
# Just finished count: 188 . Percentage done: 63.851351351351354
# http://labelme.csail.mit.edu/Annotations/static_outdoor_road_mallorca_spain/
# Just finished count: 189 . Percentage done: 64.1891891891892
# http://labelme.csail.mit.edu/Annotations/static_outdoor_road_spain/
# Just finished count: 190 . Percentage done: 64.52702702702703
# http://labelme.csail.mit.edu/Annotations/static_outdoor_santa_barbara_california_usa/
# Just finished count: 191 . Percentage done: 64.86486486486487
# http://labelme.csail.mit.edu/Annotations/static_outdoor_scenessurfaceslant_submitted_aude_oliva/
# Just finished count: 192 . Percentage done: 65.20270270270271
# http://labelme.csail.mit.edu/Annotations/static_outdoor_st_petersburg_submitted_alyosha_efros/
# Just finished count: 193 . Percentage done: 65.54054054054055
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_berkeley/
# Just finished count: 194 . Percentage done: 65.87837837837837
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_campus_maryland_usa/
# Just finished count: 195 . Percentage done: 66.21621621621621
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_amsterdam_netherlands/
# Just finished count: 196 . Percentage done: 66.55405405405405
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_barcelona_spain/
# Just finished count: 197 . Percentage done: 66.89189189189189
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_barcelona_spain_2007/
# Just finished count: 198 . Percentage done: 67.22972972972973
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_barcelona_spain_night/
# Just finished count: 199 . Percentage done: 67.56756756756756
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_cambridge_uk/
# Just finished count: 200 . Percentage done: 67.9054054054054
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_gerona_spain/
# Just finished count: 201 . Percentage done: 68.24324324324324
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_madrid_spain/
# Just finished count: 202 . Percentage done: 68.58108108108108
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_paris_france/
# Just finished count: 203 . Percentage done: 68.91891891891892
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_seatle_usa/
# Just finished count: 204 . Percentage done: 69.25675675675676
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_city_washington/
# Just finished count: 205 . Percentage done: 69.5945945945946
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_salt_lake_city/
# Just finished count: 206 . Percentage done: 69.93243243243244
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_san_jose_california/
# Just finished count: 207 . Percentage done: 70.27027027027027
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_sarasota_florida_usa_2007/
# Just finished count: 208 . Percentage done: 70.60810810810811
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_stanford/
# Just finished count: 209 . Percentage done: 70.94594594594595
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_taipei_taiwan/
# Just finished count: 210 . Percentage done: 71.28378378378379
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_valladolid_spain/
# Just finished count: 211 . Percentage done: 71.62162162162163
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_village_benavente_leon_spain/
# Just finished count: 212 . Percentage done: 71.95945945945945
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_village_galicia_spain/
# Just finished count: 213 . Percentage done: 72.29729729729729
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_village_palafrugel_spain/
# Just finished count: 214 . Percentage done: 72.63513513513513
# http://labelme.csail.mit.edu/Annotations/static_outdoor_street_village_puigpunyent_mallorca_spain/
# Just finished count: 215 . Percentage done: 72.97297297297297
# http://labelme.csail.mit.edu/Annotations/static_outdoor_urban_city_london_uk/
# Just finished count: 216 . Percentage done: 73.3108108108108
# http://labelme.csail.mit.edu/Annotations/static_outdoor_urban_city_street_astorga_leon_spain/
# Just finished count: 217 . Percentage done: 73.64864864864865
# http://labelme.csail.mit.edu/Annotations/static_outdoor_urban_city_street_boston/
# Just finished count: 218 . Percentage done: 73.98648648648648
# http://labelme.csail.mit.edu/Annotations/static_outdoor_urban_city_street_boston_snow/
# Just finished count: 219 . Percentage done: 74.32432432432432
# http://labelme.csail.mit.edu/Annotations/static_outdoor_urban_city_street_coruna_spain/
# Just finished count: 220 . Percentage done: 74.66216216216216
# http://labelme.csail.mit.edu/Annotations/static_outdoor_valladolid_street_spain/
# Just finished count: 221 . Percentage done: 75.0
# http://labelme.csail.mit.edu/Annotations/static_outdoor_village_caldes_de_montbui_spain/
# Just finished count: 222 . Percentage done: 75.33783783783784
# http://labelme.csail.mit.edu/Annotations/static_palma_outdoor_2004/
# Just finished count: 223 . Percentage done: 75.67567567567568
# http://labelme.csail.mit.edu/Annotations/static_palma_outdoor_august_2005/
# Just finished count: 224 . Percentage done: 76.01351351351352
# http://labelme.csail.mit.edu/Annotations/static_palma_outdoor_august_2005_set2/
# Just finished count: 225 . Percentage done: 76.35135135135135
# http://labelme.csail.mit.edu/Annotations/static_palma_outdoor_august_2005_set3/
# Just finished count: 226 . Percentage done: 76.6891891891892
# http://labelme.csail.mit.edu/Annotations/static_palma_outdoor_august_2005_set4/
# Just finished count: 227 . Percentage done: 77.02702702702703
# http://labelme.csail.mit.edu/Annotations/static_palma_outdoor_august_2005_set5/
# Just finished count: 228 . Percentage done: 77.36486486486487
# http://labelme.csail.mit.edu/Annotations/static_park_outdoor_boston/
# Just finished count: 229 . Percentage done: 77.70270270270271
# http://labelme.csail.mit.edu/Annotations/static_sarasota_florida_2006/
# Just finished count: 230 . Percentage done: 78.04054054054055
# http://labelme.csail.mit.edu/Annotations/static_school_cide_spain/
# Just finished count: 231 . Percentage done: 78.37837837837837
# http://labelme.csail.mit.edu/Annotations/static_silverware/
# Just finished count: 232 . Percentage done: 78.71621621621621
# http://labelme.csail.mit.edu/Annotations/static_speaker_podium_indoor_web/
# Just finished count: 233 . Percentage done: 79.05405405405405
# http://labelme.csail.mit.edu/Annotations/static_sports_outdoor/
# Just finished count: 234 . Percentage done: 79.39189189189189
# http://labelme.csail.mit.edu/Annotations/static_street_cambridge/
# Just finished count: 235 . Percentage done: 79.72972972972973
# http://labelme.csail.mit.edu/Annotations/static_street_cambridge_outdoor_july_2005/
# Just finished count: 236 . Percentage done: 80.06756756756756
# http://labelme.csail.mit.edu/Annotations/static_street_city_outdoor_caltech_pasadena_california_usa/
# Just finished count: 237 . Percentage done: 80.4054054054054
# http://labelme.csail.mit.edu/Annotations/static_street_los_angeles_usa/
# Just finished count: 238 . Percentage done: 80.74324324324324
# http://labelme.csail.mit.edu/Annotations/static_street_outdoor_night/
# Just finished count: 239 . Percentage done: 81.08108108108108
# http://labelme.csail.mit.edu/Annotations/static_street_outdoor_palma_mallorca_spain/
# Just finished count: 240 . Percentage done: 81.41891891891892
# http://labelme.csail.mit.edu/Annotations/static_street_outdoor_palma_mallorca_spain_2007/
# Just finished count: 241 . Percentage done: 81.75675675675676
# http://labelme.csail.mit.edu/Annotations/static_street_outdoor_pittsburgh_usa/
# Just finished count: 242 . Percentage done: 82.0945945945946
# http://labelme.csail.mit.edu/Annotations/static_street_statacenter_cambridge_outdoor_2005/
# Just finished count: 243 . Percentage done: 82.43243243243244
# http://labelme.csail.mit.edu/Annotations/static_street_urban_mineapolis_minesota_usa/
# Just finished count: 244 . Percentage done: 82.77027027027027
# http://labelme.csail.mit.edu/Annotations/static_street_village_fuensaldana_spain/
# Just finished count: 245 . Percentage done: 83.10810810810811
# http://labelme.csail.mit.edu/Annotations/static_submitted_3d/
# Just finished count: 246 . Percentage done: 83.44594594594595
# http://labelme.csail.mit.edu/Annotations/static_submitted_bhattacharya/
# Just finished count: 247 . Percentage done: 83.78378378378379
# http://labelme.csail.mit.edu/Annotations/static_submitted_bhattacharya2/
# Just finished count: 248 . Percentage done: 84.12162162162163
# http://labelme.csail.mit.edu/Annotations/static_submitted_billy_peralta_indoor_june_2011_test/
# Just finished count: 249 . Percentage done: 84.45945945945945
# http://labelme.csail.mit.edu/Annotations/static_submitted_billy_peralta_indoor_june_2011_train/
# Just finished count: 250 . Percentage done: 84.79729729729729
# http://labelme.csail.mit.edu/Annotations/static_submitted_central_london_streets_october_2010/
# Just finished count: 251 . Percentage done: 85.13513513513513
# http://labelme.csail.mit.edu/Annotations/static_submitted_course_6088/
# Just finished count: 252 . Percentage done: 85.47297297297297
# http://labelme.csail.mit.edu/Annotations/static_submitted_drew_linsley_kitchen_aug_2011/
# Just finished count: 253 . Percentage done: 85.8108108108108
# http://labelme.csail.mit.edu/Annotations/static_submitted_drew_linsley_sept_2011/
# Just finished count: 254 . Percentage done: 86.14864864864865
# http://labelme.csail.mit.edu/Annotations/static_submitted_ha_mai_lan_april_2010/
# Just finished count: 255 . Percentage done: 86.48648648648648
# http://labelme.csail.mit.edu/Annotations/static_submitted_konstantinos_september_2006/
# Just finished count: 256 . Percentage done: 86.82432432432432
# http://labelme.csail.mit.edu/Annotations/static_submitted_miriam_indoor_july_2011/
# Just finished count: 257 . Percentage done: 87.16216216216216
# http://labelme.csail.mit.edu/Annotations/static_submitted_nedovic_montenegro_january_2007/
# Just finished count: 258 . Percentage done: 87.5
# http://labelme.csail.mit.edu/Annotations/static_submitted_neha_parikh/
# Just finished count: 259 . Percentage done: 87.83783783783784
# http://labelme.csail.mit.edu/Annotations/static_submitted_pelz_march_2008/
# Just finished count: 260 . Percentage done: 88.17567567567568
# http://labelme.csail.mit.edu/Annotations/static_submitted_ruogo_fang_april_2010/
# Just finished count: 261 . Percentage done: 88.51351351351352
# http://labelme.csail.mit.edu/Annotations/static_submitted_rustam_antia/
# Just finished count: 262 . Percentage done: 88.85135135135135
# http://labelme.csail.mit.edu/Annotations/static_submitted_sangdon_park_abnormal_scene_named_feb_2012/
# Just finished count: 263 . Percentage done: 89.1891891891892
# http://labelme.csail.mit.edu/Annotations/static_submitted_saxena_chung_ng_nips2005_learningdepth/
# Just finished count: 264 . Percentage done: 89.52702702702703
# http://labelme.csail.mit.edu/Annotations/static_submitted_seung_kook_yun_animals_web_april_2007/
# Just finished count: 265 . Percentage done: 89.86486486486487
# http://labelme.csail.mit.edu/Annotations/static_submitted_streets_jana_ivanova_jan_2011/
# Just finished count: 266 . Percentage done: 90.20270270270271
# http://labelme.csail.mit.edu/Annotations/static_submitted_yulia_eskin_toronto_univeristy/
# Just finished count: 267 . Percentage done: 90.54054054054055
# http://labelme.csail.mit.edu/Annotations/static_vancouver_canada_outdoor_street/
# Just finished count: 268 . Percentage done: 90.87837837837837
# http://labelme.csail.mit.edu/Annotations/static_village_mallorca_outdoor/
# Just finished count: 269 . Percentage done: 91.21621621621621
# http://labelme.csail.mit.edu/Annotations/static_village_outdoor_2005/
# Just finished count: 270 . Percentage done: 91.55405405405405
# http://labelme.csail.mit.edu/Annotations/static_village_puigpunyent_mallorca_spain/
# Just finished count: 271 . Percentage done: 91.89189189189189
# http://labelme.csail.mit.edu/Annotations/static_waterfront_boston_outdoor_july_2005/
# Just finished count: 272 . Percentage done: 92.22972972972973
# http://labelme.csail.mit.edu/Annotations/static_web_indoor_home/
# Just finished count: 273 . Percentage done: 92.56756756756756
# http://labelme.csail.mit.edu/Annotations/static_web_indoor_home2/
# Just finished count: 274 . Percentage done: 92.9054054054054
# http://labelme.csail.mit.edu/Annotations/static_web_outdoor_spain/
# Just finished count: 275 . Percentage done: 93.24324324324324
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_jenny/
# Just finished count: 276 . Percentage done: 93.58108108108108
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_jenny_rome/
# Just finished count: 277 . Percentage done: 93.91891891891892
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_meg_houses/
# Just finished count: 278 . Percentage done: 94.25675675675676
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_meg_placesettings/
# Just finished count: 279 . Percentage done: 94.5945945945946
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_meg_placesettings2/
# Just finished count: 280 . Percentage done: 94.93243243243244
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_noa_ofen_jenny_chai_ef/
# Just finished count: 281 . Percentage done: 95.27027027027027
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_noa_ofen_jenny_chai_ret_images/
# Just finished count: 282 . Percentage done: 95.60810810810811
# http://labelme.csail.mit.edu/Annotations/static_web_submitted_noa_ofen_jenny_chai_stims/
# Just finished count: 283 . Percentage done: 95.94594594594595
# http://labelme.csail.mit.edu/Annotations/static_web_tinyimages_testset/
# Just finished count: 284 . Percentage done: 96.28378378378379
# http://labelme.csail.mit.edu/Annotations/static_web_tinyimagesdataset/
# Just finished count: 285 . Percentage done: 96.62162162162163
# http://labelme.csail.mit.edu/Annotations/users/
# Just finished count: 286 . Percentage done: 96.95945945945945
# http://labelme.csail.mit.edu/Annotations/valladolid_static_street/
# Just finished count: 287 . Percentage done: 97.29729729729729
# http://labelme.csail.mit.edu/Annotations/video_street_city_outdoor_boston_usa_mvi_0004/
# Just finished count: 288 . Percentage done: 97.63513513513513
# http://labelme.csail.mit.edu/Annotations/web_automatic_annotation/
# Just finished count: 289 . Percentage done: 97.97297297297297
# http://labelme.csail.mit.edu/Annotations/web_soccerField_static/
# Just finished count: 290 . Percentage done: 98.3108108108108
# http://labelme.csail.mit.edu/Annotations/web_static_homepages/
# Just finished count: 291 . Percentage done: 98.64864864864865
# http://labelme.csail.mit.edu/Annotations/web_static_office/
# Just finished count: 292 . Percentage done: 98.98648648648648
# http://labelme.csail.mit.edu/Annotations/web_static_outdoor_street_freiberg_germany/
# Just finished count: 293 . Percentage done: 99.32432432432432
# http://labelme.csail.mit.edu/Annotations/web_static_park_garden_outdoor/
# Just finished count: 294 . Percentage done: 99.66216216216216
# http://labelme.csail.mit.edu/Annotations/web_static_street_april/
# Just finished count: 295 . Percentage done: 100.0

# %%
# Store labels, in an earlier created Annotations.txt file 

folder_to_store_images = ".../data/LabelMe"
txt_path = folder_to_store_images + "/Annotations.txt"

with open(txt_path, mode="w", encoding="utf-8") as f:
    f.write(",;.,".join(labelMe_label_list))

# %%
# Download images from labelme website DELETE LATER DELETE LATER

# retrieve all folder urls which have the images
url_folders = find_folders(True)

url_folders = url_folders[0:2]

# uncomment next line for testing (here only images in the first 3 folders are downloaded)
# url_folders = url_folders[0:3]   

# Specify correct path to label me folder
folder_to_store_images = ".../data/LabelMe"

print(len(url_folders))

counter = 0

long_label_string = labelMe_label_list.join()

# Download the images (WARNING: might take a while for the full image set)
for url in url_folders:
    print(url)
    download_images(url, folder_to_store_images, counter, long_label_string)
    print("Just finished count: ", counter)
    counter += 1

# %%
folder_to_store_images = ".../data/LabelMe"
# labelMe_label_list = labelMe_label_List[:]
txt_path = folder_to_store_images + "/Annotations.txt"


with open(txt_path, "r", encoding='utf-8') as f:
    labelMe_label_list_unsplit = f.read()
    
    labelMe_label_list = labelMe_label_list_unsplit.split(",;.,")
    
print(len(labelMe_label_list))


idx = 0
for labels in labelMe_label_list:
    
    if ".jpg" in labels:
        
        stop_index = labels.find('><')
        if ()
#         print(labels[0:stop_index])
    else:
        print(labels)
        break
    idx += 1
    
print("in total", sum(".jpg" in s for s in labelMe_label_list), "occurences of .jpg in the annotations")
# Out:
# 80545
# 0abayu5pjghnpeh872w1mo0dq4wwkocc32qseh><static_houses_boston_2005>> window window window window door stairs housetop for sale sign window bushes house window window window house number flower
# in total 80383 occurences of .jpg in the annotations

# %%
# Download images from labelme website

# retrieve all folder urls which have the images
url_folders = find_folders(True)

url_folders = url_folders[0:2]

# uncomment next line for testing (here only images in the first 3 folders are downloaded)
# url_folders = url_folders[0:3]   

# Specify correct path to label me folder
folder_to_store_images = ".../data/LabelMe"


counter = 0

long_label_string = labelMe_label_list.join()

# Download the images (WARNING: might take a while for the full image set)
for url in url_folders:
    print(url)
    download_images(url, folder_to_store_images, counter, long_label_string)
    print("Just finished count: ", counter)
    counter += 1
